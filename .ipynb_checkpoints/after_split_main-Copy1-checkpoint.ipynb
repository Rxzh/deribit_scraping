# %%
#!code .

# %% [markdown]
# # Pricing d'option sur cryptomonnaies
# #### LL

# %% [markdown]
# ### Imports
#
# Les imports se font de la manière suivante
# - Le scraper se trouve dans le module Market
# - Les modèles sont dans le module Models
# - Des fonctions utiles se trouvent dans le sous-module utils du module Models, on y retrouve des fonctions d'évaluations pour les modèles

# %%
from Cryptocurrency_pricing.Market import deribit_data as dm
from Cryptocurrency_pricing.Models.utils import *
from Cryptocurrency_pricing.Models import BlackScholes, Merton, Heston

import numpy as np
import plotly.graph_objects as go

# %% [markdown]
# ### Scraping
#
# Pour effectuer le scraping de données depuis deribit, il faut instancier la classe Scraper du module deribit_data, l'argument $\verb+currency+$ permet de choisir la cryptomonnaie sur laquelle on veut récupérer les données du marché (BTC, ETH, etc...)

# %%
data = dm.Scraper(currency='BTC')

# %% [markdown]
# Une fois le scraper initialisé, on collecte la donnée par la méthode $\verb+collect_data+$.
# - $\tt{max\_workers}$ determine le nombre de threads qui vont marcher en parallèle pour scraper la donnée (20 max pour ne pas surcharger les requêtes)
# - $\tt{save\_csv = True}$ pour sauvegarder la donnée scrapée en csv.

# %%
raw_df = data.collect_data(max_workers = 15, save_csv = False)
# Out:
# Collecting data...
# Data Collected

# %%
raw_df.head(3)
# Out:
#    underlying_price underlying_index      timestamp  \
# 0          32751.06      BTC-24SEP21  1625744428898
# 1          34583.82      BTC-24JUN22  1625744428917
# 2          32540.13       BTC-9JUL21  1625744428927
#
#                                                stats state  settlement_price  \
# 0  {'volume': 1.2, 'price_change': 0.0, 'low': 0....  open              0.32
# 1  {'volume': None, 'price_change': None, 'low': ...  open              0.39
# 2  {'volume': 0.2, 'price_change': 0.9524, 'low':...  open              0.05
#
#    open_interest  min_price  max_price  mark_price  ...    change_id  \
# 0          545.5     0.2455     0.4060    0.313395  ...  32828902551
# 1            0.0     0.3165     0.4955    0.393708  ...  32828906260
# 2           20.7     0.0180     0.0920    0.051724  ...  32828906265
#
#                                                 bids  bid_iv best_bid_price  \
# 0                     [[0.3085, 0.6], [0.0005, 0.3]]   86.95         0.3085
# 1       [[0.355, 9.0], [0.1685, 0.5], [0.0005, 0.1]]   79.84         0.3550
# 2  [[0.0495, 1.0], [0.0485, 0.8], [0.048, 5.5], [...   83.40         0.0495
#
#    best_bid_amount best_ask_price  best_ask_amount  \
# 0              0.6         0.6560              0.1
# 1              9.0         0.4370              9.0
# 2              1.0         0.0555              1.0
#
#                                                 asks  ask_iv  option_type
# 0        [[0.656, 0.1], [0.7065, 0.1], [2.158, 0.5]]  282.69            P
# 1                                     [[0.437, 9.0]]  105.11            C
# 2  [[0.0555, 1.0], [0.056, 0.8], [0.0565, 5.0], [...  133.45            C
#
# [3 rows x 27 columns]

# %% [markdown]
# La donnée brute sur les options contient beaucoup d'information, elles seront traitées en amont dans les modèles.

# %% [markdown]
# ### Initialisation des modèles

# %% [markdown]
# Les modèles s'initialisent de la façon suivante, avec deux paramètres, le dataframe brut scrapé, ainsi que le type d'option à garder : $$\tt{ \{C : Call, P : Put, B : Both\} }$$

# %%
BS = BlackScholes(raw_df.copy(), 'C')
M = Merton(raw_df.copy(), 'C')
H = Heston(raw_df.copy(), 'C')
# Out:
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mid_iv'] = (df.bid_iv + df.ask_iv)/2
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['_T'] = df['_T'].apply(to_ts) - datetime.datetime.timestamp(datetime.datetime.today())#btc_subset['timestamp'].apply(ms_to_s)
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['_T'] = df['_T'].apply(ts_to_years)
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bids'] = df['bids'].apply(somme_ponderee)
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asks'] = df['asks'].apply(somme_ponderee)
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mid'] = (df.bids+df.asks)/2
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mid_iv'] = (df.bid_iv + df.ask_iv)/2
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['_T'] = df['_T'].apply(to_ts) - datetime.datetime.timestamp(datetime.datetime.today())#btc_subset['timestamp'].apply(ms_to_s)
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['_T'] = df['_T'].apply(ts_to_years)
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bids'] = df['bids'].apply(somme_ponderee)
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asks'] = df['asks'].apply(somme_ponderee)
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mid'] = (df.bids+df.asks)/2
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mid_iv'] = (df.bid_iv + df.ask_iv)/2
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['_T'] = df['_T'].apply(to_ts) - datetime.datetime.timestamp(datetime.datetime.today())#btc_subset['timestamp'].apply(ms_to_s)
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['_T'] = df['_T'].apply(ts_to_years)
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bids'] = df['bids'].apply(somme_ponderee)
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['asks'] = df['asks'].apply(somme_ponderee)
# /Users/pierrebelamri/Documents/GitHub/deribit_scraping/Cryptocurrency_pricing/Models/utils.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['mid'] = (df.bids+df.asks)/2

# %% [markdown]
# Chaque modèle possède désormais un DataFrame $\tt{df}$ trié lors de l'initialisation des modèles par la pipeline de tri du module $\tt{utils}$, il ne contient que les informations utiles pour la suite.

# %%
BS.df.tail(25)
# Out:
#             S        K      V        _T      bids      asks  last_price  \
# 13   32529.42  42000.0   24.5  0.039534  0.003807  0.006426      0.0045
# 217  32518.39  45000.0   34.3  0.039534  0.001638  0.003753      0.0025
# 243  32522.85  50000.0   20.6  0.039534  0.000500  0.002689      0.0005
# 260  32524.65  32000.0   20.8  0.058712  0.086263  0.138305      0.0875
# 331  32523.35  34000.0   29.9  0.058712  0.058178  0.063299      0.0595
# 38   32525.18  35000.0   45.3  0.058712  0.043256  0.054526      0.0470
# 340  32524.40  36000.0  532.4  0.058712  0.036490  0.048507      0.0400
# 348  32523.36  40000.0  250.3  0.058712  0.014000  0.026555      0.0160
# 124  32518.99  45000.0   28.4  0.058712  0.004133  0.009977      0.0060
# 54   32523.89  50000.0   46.5  0.058712  0.001948  0.011170      0.0030
# 93   32525.31  55000.0    5.7  0.058712  0.001005  0.007488      0.0020
# 100  32637.70  35000.0   34.3  0.135424  0.090808  0.104488      0.0995
# 75   32638.29  40000.0   89.4  0.135424  0.051407  0.082951      0.0547
# 222  32631.28  45000.0   63.4  0.135424  0.027733  0.035123      0.0295
# 252  32637.88  50000.0   37.9  0.135424  0.016008  0.021255      0.0170
# 352  32636.43  55000.0   26.1  0.135424  0.009920  0.024652      0.0115
# 264  32636.79  60000.0    5.2  0.135424  0.006472  0.011041      0.0080
# 179  32630.95  70000.0   12.9  0.135424  0.003118  0.008121      0.0040
# 19   32750.53  32000.0    8.6  0.212137  0.123362  0.256483      0.1795
# 302  32749.28  36000.0    8.5  0.212137  0.119017  0.131608      0.1355
# 88   32750.72  40000.0   46.5  0.212137  0.077597  0.122075      0.0900
# 279  32748.64  48000.0   12.1  0.212137  0.041361  0.073731      0.0485
# 242  32750.21  50000.0   10.3  0.212137  0.038305  0.059691      0.0420
# 181  32743.20  56000.0   30.5  0.212137  0.026126  0.070453      0.0275
# 248  32750.03  72000.0   17.2  0.212137  0.007441  0.049783      0.0110
#
#      mark_price option_type   mid_iv  mark_iv       mid  moneyness
# 13     0.004593           C   80.260    80.69  0.005117   0.774510
# 217    0.002368           C   86.350    85.70  0.002695   0.722631
# 243    0.000738           C   90.835    91.13  0.001594   0.650457
# 260    0.089567           C   83.740    84.05  0.112284   1.016395
# 331    0.060733           C   81.225    81.70  0.060739   0.956569
# 38     0.049030           C   80.295    80.60  0.048891   0.929291
# 340    0.039305           C   79.490    79.85  0.042499   0.903456
# 348    0.016127           C   79.755    79.97  0.020278   0.813084
# 124    0.006106           C   84.400    84.72  0.007055   0.722644
# 54     0.003050           C   91.945    92.32  0.006559   0.650478
# 93     0.001783           C   99.550    99.91  0.004246   0.591369
# 100    0.098456           C   86.330    86.47  0.097648   0.932506
# 75     0.054548           C   85.275    85.51  0.067179   0.815957
# 222    0.030493           C   86.055    86.27  0.031428   0.725140
# 252    0.017863           C   88.035    88.20  0.018631   0.652758
# 352    0.011217           C   91.005    90.97  0.017286   0.593390
# 264    0.007800           C   94.585    94.75  0.008757   0.543946
# 179    0.004548           C  102.570   102.81  0.005620   0.466156
# 19     0.174829           C   90.165    90.21  0.189922   1.023454
# 302    0.127269           C   89.830    89.84  0.125313   0.909702
# 88     0.091969           C   89.545    89.67  0.099836   0.818768
# 279    0.049740           C   91.160    91.16  0.057546   0.682263
# 242    0.043113           C   91.660    91.75  0.048998   0.655004
# 181    0.028709           C   93.690    93.66  0.048289   0.584700
# 248    0.012398           C  100.600   100.47  0.028612   0.454862

# %% [markdown]
# La méthode $\tt{initialize}$ permet d'initialiser les paramètres propres à chaque modèle, depuis un vecteur $\theta$, le booléen $\tt{reset}$ permet de choisir de réinitialiser aux derniers paramètres calibrés enregistrés.

# %%
BS.initialize(reset = True)
M.initialize(reset = True)
H.initialize(reset = True)

# %% [markdown]
# ### Ajouts des volatiliés implicites

# %% [markdown]
# La méthode append_imp_vol_to_df ajoute une colonne au DataFrame du modèle avec les volatilités implicites, calculées  dans le module $\tt{common\_all}$

# %%
BS.append_imp_vol_to_df()
M.append_imp_vol_to_df()
H.append_imp_vol_to_df()

# %% [markdown]
# ### Ajouts des Prix respectifs de chaque modèles aux df
#
# Chaque modèle possède une méthode $\tt{Price}$ qui calcule le prix d'une option sous ce modèle.

# %%
S = 34205.37
K = 35000.0
T = 0.067142
v = 0.028870
Flag = 'C'
print("Black-Scholes Price : ${}".format(S*BS.Price(S=S, K=K, T=T, sigma=v, CallPutFlag=Flag)))
print("Merton Price        : ${}".format(S*M.Price(S=S, K=K, T=T, sigma=v, CallPutFlag=Flag)))
print("Heston Price        : ${}".format(S*H.Price(S=S, K=K, T=T, sigma=v, CallPutFlag=Flag)))
print("Market Price        : ${}".format(S*0.077089))
# Out:
# Black-Scholes Price : $3626.812075362676
# Merton Price        : $3629.7543747284208
# Heston Price        : $2996.9214525019
# Market Price        : $2636.8577679300006

# %% [markdown]
# La vectorisation de cette fonction et son application aux lignes du DataFrame permet de calculer une liste de prix qui pourront être comparés avec ceux du marché. Cela ce fait via la méthode $\tt{append\_price}$.

# %%
BS.append_price()
M.append_price()
H.append_price()

BS.df[['BS_PRICE','mid']].head()
# Out:
#      BS_PRICE       mid
# 57   0.010564  0.010446
# 85   0.023058  0.022972
# 317  0.022446  0.022391
# 161  0.008899  0.008882
# 265  0.001506  0.001503

# %%
bad_prices_indexes = H.df[H.df.mid >= 1].index


BS.df = BS.df.drop(bad_prices_indexes)
H.df = H.df.drop(bad_prices_indexes)
M.df = M.df.drop(bad_prices_indexes)

bad_prices_indexes =  BS.df[BS.df.BS_PRICE >= 1].index

BS.df = BS.df.drop(bad_prices_indexes)
H.df = H.df.drop(bad_prices_indexes)
M.df = M.df.drop(bad_prices_indexes)


bad_prices_indexes =  M.df[M.df.MERTON_PRICE >= 1].index

BS.df = BS.df.drop(bad_prices_indexes)
H.df = H.df.drop(bad_prices_indexes)
M.df = M.df.drop(bad_prices_indexes)

bad_prices_indexes =  H.df[H.df.HESTON_PRICE >= 1].index

BS.df = BS.df.drop(bad_prices_indexes)
H.df = H.df.drop(bad_prices_indexes)
M.df = M.df.drop(bad_prices_indexes)

# %%
#H.df[H.df.mid >= 0].index

# %% [markdown]
# ### Optimisation des paramètres (pour Merton et Heston)

# %%
H.optimize(x0 = None, tol = 1e-4, max_iter =700, update_when_done=True )
# Out:
# array([0.72080248, 0.20103026, 0.99892212, 0.60342072, 1.13825502])

# %%
M.optimize(tol = 1e-4, max_iter=700, update_when_done=True)
# Out:
# array([1.e-02, 1.e-05, 0.e+00])

# %%
from sklearn.metrics import mean_absolute_error

x = BS.df['K']
y = BS.df['_T']
z = BS.df['mid']

x1 = BS.df['K']
y1 = BS.df['_T']
z1 = BS.df['BS_PRICE']

x2 = M.df['K']
y2 = M.df['_T']
z2 = M.df['MERTON_PRICE']

x3 = H.df['K']
y3 = H.df['_T']
z3 = H.df['HESTON_PRICE']






fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z , mode='markers', name='Real Market Price', marker=dict(opacity=0.8)),
                      go.Scatter3d(x=x1, y=y1, z=z1, mode='markers', name='BlackScholes Model Price', marker=dict(opacity=0.8)),
                      go.Scatter3d(x=x2, y=y2, z=z2, mode='markers', name='Merton Model Price', marker=dict(opacity=0.8),),
                      go.Scatter3d(x=x3, y=y3, z=z3, mode='markers', name='Heston Model Price', marker=dict(opacity=0.8))])


fig.update_scenes(xaxis_title_text='Strike', yaxis_title_text='Exp', zaxis_title_text='Price') 
fig.show()

#rms_merton = mean_squared_error(z2, z3, squared=False)
# Out:
# <div>                            <div id="5f144e46-0be9-4a8b-a627-0cf20f34ed53" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f144e46-0be9-4a8b-a627-0cf20f34ed53")) {                    Plotly.newPlot(                        "5f144e46-0be9-4a8b-a627-0cf20f34ed53",                        [{"marker": {"opacity": 0.8}, "mode": "markers", "name": "Real Market Price", "type": "scatter3d", "x": [33000.0, 34000.0, 35000.0, 36000.0, 37000.0, 38000.0, 40000.0, 33000.0, 34000.0, 33000.0, 34000.0, 35000.0, 36000.0, 37000.0, 38000.0, 40000.0, 42000.0, 45000.0, 34000.0, 36000.0, 38000.0, 40000.0, 42000.0, 45000.0, 50000.0, 34000.0, 35000.0, 36000.0, 40000.0, 45000.0, 50000.0, 55000.0, 35000.0, 40000.0, 45000.0, 50000.0, 55000.0, 60000.0, 70000.0, 36000.0, 40000.0, 48000.0, 50000.0, 56000.0, 72000.0], "y": [0.0011776979048048887, 0.0011776979048048887, 0.0011776979048048887, 0.0011776979048048887, 0.0011776979048048887, 0.0011776979048048887, 0.0011776979048048887, 0.003917423932202149, 0.003917423932202149, 0.020355780096585712, 0.020355780096585712, 0.020355780096585712, 0.020355780096585712, 0.020355780096585712, 0.020355780096585712, 0.020355780096585712, 0.020355780096585712, 0.020355780096585712, 0.039533862288366535, 0.039533862288366535, 0.039533862288366535, 0.039533862288366535, 0.039533862288366535, 0.039533862288366535, 0.039533862288366535, 0.058711944480147354, 0.058711944480147354, 0.058711944480147354, 0.058711944480147354, 0.058711944480147354, 0.058711944480147354, 0.058711944480147354, 0.13542427324727063, 0.13542427324727063, 0.13542427324727063, 0.13542427324727063, 0.13542427324727063, 0.13542427324727063, 0.13542427324727063, 0.21213660201439394, 0.21213660201439394, 0.21213660201439394, 0.21213660201439394, 0.21213660201439394, 0.21213660201439394], "z": [0.010446114252573583, 0.022971699209669922, 0.02239106859886012, 0.008881766917293235, 0.0015033866995073893, 0.008822049405306495, 0.0005442942942942945, 0.01746550539712591, 0.007741608764612388, 0.04167082048358256, 0.028956631275444525, 0.019886581407398844, 0.015715101650563612, 0.00889076621982549, 0.0067638775688420565, 0.0031000425959806163, 0.0021899465114714406, 0.0010700549450549453, 0.04544493512332991, 0.026027864196225735, 0.014551793080866637, 0.008210523128667923, 0.005116548248089058, 0.0026953142151781135, 0.001594300822561692, 0.06073891174383879, 0.04889123919001752, 0.042498500787885016, 0.020277578328981725, 0.007055316312197623, 0.006558882060479778, 0.004246400239044424, 0.09764791474602985, 0.06717897860593514, 0.03142798365670407, 0.018631203007518797, 0.017285984602110577, 0.008756611895224711, 0.005619524657223912, 0.1253125570721536, 0.09983589473294867, 0.05754594104862526, 0.048997991582982625, 0.048289479884310406, 0.02861190076171949]}, {"marker": {"opacity": 0.8}, "mode": "markers", "name": "BlackScholes Model Price", "type": "scatter3d", "x": [33000.0, 34000.0, 35000.0, 36000.0, 37000.0, 38000.0, 40000.0, 33000.0, 34000.0, 33000.0, 34000.0, 35000.0, 36000.0, 37000.0, 38000.0, 40000.0, 42000.0, 45000.0, 34000.0, 36000.0, 38000.0, 40000.0, 42000.0, 45000.0, 50000.0, 34000.0, 35000.0, 36000.0, 40000.0, 45000.0, 50000.0, 55000.0, 35000.0, 40000.0, 45000.0, 50000.0, 55000.0, 60000.0, 70000.0, 36000.0, 40000.0, 48000.0, 50000.0, 56000.0, 72000.0], "y": [0.0011776979048048887, 0.0011776979048048887, 0.0011776979048048887, 0.0011776979048048887, 0.0011776979048048887, 0.0011776979048048887, 0.0011776979048048887, 0.003917423932202149, 0.003917423932202149, 0.020355780096585712, 0.020355780096585712, 0.020355780096585712, 0.020355780096585712, 0.020355780096585712, 0.020355780096585712, 0.020355780096585712, 0.020355780096585712, 0.020355780096585712, 0.039533862288366535, 0.039533862288366535, 0.039533 ...

# %%
Eval_Metrics(BS=BS,M=M,H=H)
# Out:
# =============== Root Mean Squared Error ================
#
# B&S    = 0.806 %
# MERTON    = 0.806 %
# HESTON    = 0.653 %
#
# =============== Mean Absolute Error ================
#
# B&S    = 0.335 %
# MERTON    = 0.335 %
# HESTON    = 0.423 %
#
# =============== R2 Score ================
#
# B&S    = 94.697 %
# MERTON    = 94.697 %
# HESTON    = 94.784 %

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
mkt  = pd.DataFrame([BS.df['_T'],BS.df['K'],BS.df['mid'],BS.df['BS_PRICE'],H.df['HESTON_PRICE'],M.df['MERTON_PRICE']]).T

mkt.dropna(inplace = True)
L_T = []

for T in mkt['_T']:
    
    extract_mkt = mkt[mkt._T == T]
    

    plt.plot(extract_mkt['K'],extract_mkt['mid'],label='Market Price')
    plt.plot(extract_mkt['K'],extract_mkt['BS_PRICE'], label='Black-Scholes Price')
    #plt.plot(extract_mkt['K'],extract_mkt['MERTON_PRICE'], label='Merton Price')
    #plt.plot(extract_mkt['K'],extract_mkt['HESTON_PRICE'],label='Heston Price')
    plt.legend()
    plt.show()

# %% [markdown]
# finir git
# tests unitaires
# heston + sauts

# %%
# Out:
#      BS_PRICE       mid
# 57   0.010564  0.010446
# 85   0.023058  0.022972
# 317  0.022446  0.022391
# 161  0.008899  0.008882
# 265  0.001506  0.001503
# 244  0.008834  0.008822
# 320  0.000545  0.000544
# 126  0.018083  0.017466
# 59   0.007852  0.007742
# 77   0.048786  0.041671
# 89   0.030830  0.028957
# 62   0.020741  0.019887
# 49   0.016230  0.015715
# 296  0.009139  0.008891
# 42   0.006928  0.006764
# 347  0.003162  0.003100
# 101  0.002227  0.002190
# 113  0.001086  0.001070
# 52   0.050962  0.045445
# 86   0.027617  0.026028
# 226  0.015192  0.014552
# 360  0.008505  0.008211
# 13   0.005275  0.005117
# 217  0.002766  0.002695
# 243  0.001628  0.001594
# 331  0.071501  0.060739
# 38   0.054504  0.048891
# 340  0.046177  0.042499
# 348  0.021272  0.020278
# 124  0.007309  0.007055
# 54   0.006742  0.006559
# 93   0.004349  0.004246
# 100  0.123925  0.097648
# 75   0.074129  0.067179
# 222  0.033751  0.031428
# 252  0.019749  0.018631
# 352  0.018154  0.017286
# 264  0.009163  0.008757
# 179  0.005839  0.005620
# 302  0.165381  0.125313
# 88   0.115921  0.099836
# 279  0.062959  0.057546
# 242  0.053266  0.048998
# 181  0.051674  0.048289
# 248  0.030099  0.028612
