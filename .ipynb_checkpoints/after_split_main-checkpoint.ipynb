# %%
#!code .

# %% [markdown]
# # Pricing d'option sur cryptomonnaies
# #### LL

# %% [markdown]
# ### Imports
#
# TODO

# %%
from Cryptocurrency_pricing.Market import deribit_data as dm
#from Cryptocurrency_pricing.Models.utils import *
from Cryptocurrency_pricing.Models import BlackScholes, Merton, Heston

import numpy as np
from sklearn.metrics import mean_squared_error
import plotly.graph_objects as go

# %% [markdown]
# ### Scraping
#
# TODO

# %%
data = dm.Scraper(currency='BTC')

# %%
raw_df = data.collect_data(max_workers = 15, save_csv = False)
# Out:
# Collecting data...
# Data Collected

# %%
#raw_df.head()

# %% [markdown]
# ### Initialisation des modèles

# %%
BS = BlackScholes(raw_df.copy(), 'B')
M = Merton(raw_df.copy(), 'B')
H = Heston(raw_df.copy(), 'B')

# %%
BS.initialize(reset = True)
M.initialize(reset = True)
H.initialize(reset = True)

# %% [markdown]
# ### Ajouts des volatiliés implicites

# %%
BS.append_imp_vol_to_df()
M.append_imp_vol_to_df()
H.append_imp_vol_to_df()

# %% [markdown]
# ### Ajouts des Prix respectifs de chaque modèles aux df
#
# Mettre ça automatiquement ?

# %%
BS.append_price()
M.append_price()
H.append_price()

# %%
bad_prices_indexes = H.df[H.df.mid >= 1].index


BS.df = BS.df.drop(bad_prices_indexes)
H.df = H.df.drop(bad_prices_indexes)
M.df = M.df.drop(bad_prices_indexes)

bad_prices_indexes =  BS.df[BS.df.BS_PRICE >= 1].index

BS.df = BS.df.drop(bad_prices_indexes)
H.df = H.df.drop(bad_prices_indexes)
M.df = M.df.drop(bad_prices_indexes)

# %%
H.df[H.df.mid >= 0].index
# Out:
# Int64Index([210,  23, 388, 225, 124, 143,  68, 319, 191, 253, 275, 244, 379,
#             304, 202, 214, 383, 338, 173, 287, 265, 342,  99, 281, 254, 328,
#              34,  69, 284, 378,  77,  64,  53,  45, 367, 106,  32,  46,  31,
#              54, 240, 381,  14, 230, 356,   9, 103,  87, 130, 312, 313,  43,
#             360, 368, 134,  58, 101,  27, 296, 162, 359, 109, 242, 268, 375,
#             286, 190, 135, 102, 180, 347],
#            dtype='int64')

# %% [markdown]
# ### Optimisation des paramètres (pour Merton et Heston)

# %%
x0 = [0.08, 0.10, 0.8, 3, 0.25]
H.optimize(x0, tol = 1e-3, max_iter =100, update_when_done=True )
# Out:
# array([0.97690492, 0.28248612, 0.79464741, 2.99227926, 0.2308499 ])

# %%
M.optimize(tol = 1e-8, max_iter=300, update_when_done=True)
# Out:
# array([1.11816807e+00, 2.63347099e-01, 1.58490533e-04])

# %%
from sklearn.metrics import mean_absolute_error

x = BS.df['K']
y = BS.df['_T']
z = BS.df['mid']

x1 = BS.df['K']
y1 = BS.df['_T']
z1 = BS.df['BS_PRICE']

x2 = M.df['K']
y2 = M.df['_T']
z2 = M.df['MERTON_PRICE']

x3 = H.df['K']
y3 = H.df['_T']
z3 = H.df['HESTON_PRICE']






fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z , mode='markers', name='Real Market Price', marker=dict(opacity=0.8)),
                      go.Scatter3d(x=x1, y=y1, z=z1, mode='markers', name='BlackScholes Model Price', marker=dict(opacity=0.8)),
                      go.Scatter3d(x=x2, y=y2, z=z2, mode='markers', name='Merton Model Price', marker=dict(opacity=0.8),),
                      go.Scatter3d(x=x3, y=y3, z=z3, mode='markers', name='Heston Model Price', marker=dict(opacity=0.8))])


fig.update_scenes(xaxis_title_text='Strike', yaxis_title_text='Exp', zaxis_title_text='Price') 
fig.show()

#rms_merton = mean_squared_error(z2, z3, squared=False)
# Out:
# <div>                            <div id="539548ce-ed73-4312-bedb-0062df5c5e1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("539548ce-ed73-4312-bedb-0062df5c5e1b")) {                    Plotly.newPlot(                        "539548ce-ed73-4312-bedb-0062df5c5e1b",                        [{"marker": {"opacity": 0.8}, "mode": "markers", "name": "Real Market Price", "type": "scatter3d", "x": [30000.0, 32000.0, 33000.0, 34000.0, 35000.0, 36000.0, 37000.0, 38000.0, 25000.0, 26000.0, 28000.0, 29000.0, 30000.0, 31000.0, 32000.0, 33000.0, 34000.0, 35000.0, 36000.0, 37000.0, 38000.0, 40000.0, 42000.0, 20000.0, 24000.0, 26000.0, 28000.0, 30000.0, 31000.0, 32000.0, 34000.0, 35000.0, 36000.0, 38000.0, 40000.0, 42000.0, 28000.0, 30000.0, 32000.0, 34000.0, 38000.0, 40000.0, 42000.0, 45000.0, 20000.0, 25000.0, 26000.0, 28000.0, 30000.0, 32000.0, 34000.0, 35000.0, 36000.0, 40000.0, 45000.0, 50000.0, 55000.0, 60000.0, 20000.0, 25000.0, 30000.0, 35000.0, 45000.0, 50000.0, 55000.0, 60000.0, 70000.0, 20000.0, 30000.0, 32000.0, 60000.0], "y": [0.001785598397738797, 0.001785598397738797, 0.001785598397738797, 0.001785598397738797, 0.001785598397738797, 0.001785598397738797, 0.001785598397738797, 0.001785598397738797, 0.010004776479930578, 0.010004776479930578, 0.010004776479930578, 0.010004776479930578, 0.010004776479930578, 0.010004776479930578, 0.010004776479930578, 0.010004776479930578, 0.010004776479930578, 0.010004776479930578, 0.010004776479930578, 0.010004776479930578, 0.010004776479930578, 0.010004776479930578, 0.010004776479930578, 0.0291828586717114, 0.0291828586717114, 0.0291828586717114, 0.0291828586717114, 0.0291828586717114, 0.0291828586717114, 0.0291828586717114, 0.0291828586717114, 0.0291828586717114, 0.0291828586717114, 0.0291828586717114, 0.0291828586717114, 0.0291828586717114, 0.04836094086349222, 0.04836094086349222, 0.04836094086349222, 0.04836094086349222, 0.04836094086349222, 0.04836094086349222, 0.04836094086349222, 0.04836094086349222, 0.06753902305527304, 0.06753902305527304, 0.06753902305527304, 0.06753902305527304, 0.06753902305527304, 0.06753902305527304, 0.06753902305527304, 0.06753902305527304, 0.06753902305527304, 0.06753902305527304, 0.06753902305527304, 0.06753902305527304, 0.06753902305527304, 0.06753902305527304, 0.14425135182239632, 0.14425135182239632, 0.14425135182239632, 0.14425135182239632, 0.14425135182239632, 0.14425135182239632, 0.14425135182239632, 0.14425135182239632, 0.14425135182239632, 0.22096368058951962, 0.22096368058951962, 0.22096368058951962, 0.22096368058951962], "z": [0.0013668877309332072, 0.0032668352115665985, 0.0067587355404866364, 0.01451690208571257, 0.010187958103226754, 0.0035278364873917666, 0.0013947645818692905, 0.0009098114824335904, 0.001641109973578983, 0.001835398767242136, 0.005124620578311252, 0.004316280186951654, 0.01632655499578639, 0.009565795717458997, 0.014384850562033829, 0.021766618171775318, 0.03744334636047128, 0.026213887813739564, 0.02137663652579028, 0.008997577629617871, 0.006222928201038125, 0.002548095438095532, 0.0015646771207837172, 0.0016811578006258384, 0.0036684166828179756, 0.0061575498430258, 0.01098222496995966, 0.019415243261222632, 0.025541422649950164, 0.033296425719449296, 0.0554907177788037, 0.05149165370779597, 0.036455648123598375, 0.01971046343840905, 0.010386935671571534, 0.005579647123410847, 0.019643147228522024, 0.031115910370182277, 0.048108569998302764, 0.0721653054303156, 0.03350130145892681, 0.020484044350172415, 0.012824971687505744, 0.006652054658203331, 0.00604270444431937, 0.024770374676390608, 0.020614261431507366, 0.03180087010339304, 0.04331343613217356, 0.11669384118224843, 0.08768465023242912, 0.08047870776874863, 0.06615401458226945, 0.03369750565668106, 0.012266105158321314, 0.008771491516 ...
# Root Mean Squared Error | B&S    = 2.096686 %
# Root Mean Squared Error | MERTON    = 1.38589 %
# Root Mean Squared Error | HESTON    = 1.77546 %
# ===============================
# Mean Absolute Error | B&S    = 0.634692 %
# Mean Absolute Error | MERTON    = 0.750035 %
# Mean Absolute Error | HESTON    = 1.165273 %

# %%
#option.init_merton(m = 0.625038301534241, lam =0.0010591027301815744, v = 0.511097066109511,  )
option.init_merton(reset=True)
option.init_heston(reset=True)

# %%
option.append_imp_vol_to_df()
option.append_loc_vol_to_df()

# %%
option.append_BS_price()

# %%
option.df.dropna(inplace=True)
option.df = option.df.drop(option.df[option.df.BS_PRICE >= 5].index) #a revoir
#option.df = option.df.drop(option.df[option.df.IV_moneyness >= .5*10**6].index)

# %%
#option.optimize_merton(tol = 1e-6, max_iter = 600)

# %%
option.append_Merton_price()
option.append_Heston_prices()

# %%
x = option.df['S']/option.df['K']

#x = option.df['K']
y = option.df['_T']
z = option.df['L_VOL']
z2 = option.df['mark_iv']/100


fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z , mode='markers', name='Local vol')])
#fig = go.Figure(data=[go.Surface(x=x, y=y, z=z , name='Local vol')])
                      #go.Scatter3d(x=x, y=y, z=z2 , mode='markers', name='Implied vol deribit')])
"""
fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z , mode='markers', name='Black&Scholes model Price'),
                      go.Scatter3d(x=x, y=y, z=z2, mode='markers', name='Real Market Price')])
"""

fig.update_scenes(xaxis_title_text='S/K', yaxis_title_text='Exp', zaxis_title_text='IV') 
fig.show()

# %%
#LINEAR INTERPOLATION
new_df = option.df[['moneyness', '_T', 'I_VOL_BS']]
new_df = new_df.pivot(index = '_T',columns='moneyness', values='I_VOL_BS')

new_df=new_df.interpolate(method='linear',axis=1,limit_direction='both')
z = new_df
x = list(new_df.columns)
y = list(new_df.index)


fig = go.Figure(data=[go.Surface(z=z, x=x, y=y)])
fig.update_layout(title='Implied Volatility', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))
fig.update_scenes(xaxis_title_text='S/K', yaxis_title_text='Exp', zaxis_title_text='IV') 
fig.show()

# %%
#LINEAR INTERPOLATION
new_df = option.df[['moneyness', '_T', 'L_VOL']]
new_df = new_df.pivot(index = '_T',columns='moneyness', values='L_VOL')

new_df=new_df.interpolate(method='linear',axis=1,limit_direction='both')
z = new_df
x = list(new_df.columns)
y = list(new_df.index)


fig = go.Figure(data=[go.Surface(z=z, x=x, y=y)])
fig.update_layout(title='Local Volatility', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig.update_scenes(xaxis_title_text='S/K', yaxis_title_text='Exp', zaxis_title_text='Local Vol') 
fig.show()

# %%
new_df = option.df[['K', '_T', 'L_VOL']]
new_df = new_df.pivot(index = '_T',columns='K', values='L_VOL')

new_df=new_df.interpolate(method='spline',order=2,axis=1)
z = new_df
x = list(new_df.columns)
y = list(new_df.index)


fig = go.Figure(data=[go.Surface(z=z, x=x, y=y)])
fig.update_layout(title='xxx', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))
fig.show()

# %%
#option.init_merton(m = 0.625038301534241, lam =0.0010591027301815744, v = 0.511097066109511,  )
option.init_merton(reset=True)
option.append_Merton_price()
rms = mean_squared_error(option.df['MERTON_PRICE'], option.df['mid'], squared=False)
print('Root Mean Squared Error = {}%'.format(round(rms*100,3)))

# %%
option.df.dropna(inplace=True)
#option.df = option.df.drop(option.df[option.df._T >= .08].index)

# %% [markdown]
# ## Test optim Heston

# %%
x0 = np.array([0.08, 0.10, 0.8, 3, 0.25])
res = option.optimize_heston(x0,tol = 1e-5, max_iter =300 )

# %%
option.init_heston(theta = res)
option.append_Heston_prices()

# %%
np.size(option.df['S'])

# %% [markdown]
# finir git
# tests unitaires
# heston + sauts
